# %% [markdown]
# # Exercise 02: Model Evaluation & Validation
# INF-8239 - Ciencia de Datos II

# %%
# Imports and environment setup
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

print("Environment initialized for Exercise 02.")
