# %% [markdown]
# # Exercise 02: Model Evaluation & Validation
# INF-8239 - Ciencia de Datos II

# %%
# Setup and baseline imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

print("Environment ready for Model Evaluation.")
