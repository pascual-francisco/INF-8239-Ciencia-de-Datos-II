# %% [markdown]
# <a href="https://colab.research.google.com/github/pascual-francisco/INF-8239-Ciencia-de-Datos-II/blob/main/Unit_01_Advanced_Data_Analysis/Exercises/Exercise_01/Exercise_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("INF-8239 Data Science II")
print("GitHub integration test")
# Out:
# INF-8239 Data Science II
# GitHub integration test
